# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.7/dist-packages (1.26.0)

# %%
# !sudo apt install build-essential libpoppler-cpp-dev pkg-config python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
#   cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1 cuda-nsight-compute-10-0
#   cuda-nsight-compute-10-1 cuda-nsight-compute-11-0 cuda-nsight-compute-11-1
#   cuda-nsight-systems-10-1 cuda-nsight-systems-11-0 cuda-nsight-systems-11-1
#   cuda-nvcc-10-0 cuda-nvcc-10-1 cuda-nvcc-11-0 cuda-nvdisasm-10-0
#   cuda-nvdisasm-10-1 cuda-nvdisasm-11-0 cuda-nvml-dev-10-0 cuda-nvml-dev-10-1
#   cuda-nvml-dev-11-0 cuda-nvprof-10-0 cuda-nvprof-10-1 cuda-nvprof-11-0
#   cuda-nvprune-10-0 cuda-nvprune-10-1 cuda-nvprune-11-0 cuda-nvtx-10-0
#   cuda-nvtx-10-1 cuda-nvtx-11-0 cuda-nvvp-10-0 cuda-nvvp-10-1 cuda-nvvp-11-0
#   cuda-nvvp-11-1 cuda-samples-10-0 cuda-samples-10-1 cuda-samples-11-0
#   cuda-samples-11-1 cuda-sanitizer-11-0 cuda-sanitizer-api-10-1
#   cuda-toolkit-10-0 cuda-toolkit-10-1 cuda-toolkit-11-0 cuda-toolkit-11-1
#   cuda-tools-10-0 cuda-tools-10-1 cuda-tools-11-0 cuda-tools-11-1
#   cuda-visual-tools-10-0 cuda-visual-tools-10-1 cuda-visual-tools-11-0
#   cuda-visual-tools-11-1 default-jre dkms freeglut3 freeglut3-dev
#   keyboard-configuration libargon2-0 libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfontenc1 libidn11 libip4tc0 libjansson4
#   libnvidia-cfg1-510 libnvidia-common-460 libnvidia-common-510
#   libnvidia-extra-510 libnvidia-fbc1-510 libnvidia-gl-510 libpam-systemd
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0 libxfont2
#   libxi-dev libxkbfile1 libxmu-dev libxmu-headers libxnvctrl0 libxtst6
#   nsight-compute-2020.2.1 nsight-compute-2022.1.0 nsight-systems-2020.3.2
#   nsight-systems-2020.3.4 nsight-systems-2021.5.2 nvidia-dkms-510
#   nvidia-kernel-common-510 nvidia-kernel-source-510 nvidia-modprobe
#   nvidia-settings openjdk-11-jre policykit-1 policykit-1-gnome python3-xkit
#   screen-resolution-extra systemd systemd-sysv udev x11-xkb-utils
#   xserver-common xserver-xorg-core-hwe-18.04 xserver-xorg-video-nvidia-510
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libpoppler-cpp0v5
# The following NEW packages will be installed:
#   libpoppler-cpp-dev libpoppler-cpp0v5
# 0 upgraded, 2 newly installed, 0 to remove and 39 not upgraded.
# Need to get 36.7 kB of archives.
# After this operation, 188 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp0v5 amd64 0.62.0-2ubuntu2.12 [28.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp-dev amd64 0.62.0-2ubuntu2.12 [8,676 B]
# Fetched 36.7 kB in 1s (65.9 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpoppler-cpp0v5:amd64.
# (Reading database ... 155113 files and directories currently installed.)
# Preparing to unpack .../libpoppler-cpp0v5_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking libpoppler-cpp0v5:amd64 (0.62.0-2ubuntu2.12) ...
# Selecting previously unselected package libpoppler-cpp-dev:amd64.
# Preparing to unpack .../libpoppler-cpp-dev_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking libpoppler-cpp-dev:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libpoppler-cpp0v5:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libpoppler-cpp-dev:amd64 (0.62.0-2ubuntu2.12) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !pip install pdftotext
# Out:
# Collecting pdftotext
#   Downloading pdftotext-2.2.2.tar.gz (113 kB)
#      |████████████████████████████████| 113 kB 8.2 MB/s
# Building wheels for collected packages: pdftotext
#   Building wheel for pdftotext (setup.py) ... done
#   Created wheel for pdftotext: filename=pdftotext-2.2.2-cp37-cp37m-linux_x86_64.whl size=54910 sha256=3c0c401f87f02aa8d5652fa3ae7555f4829163e83decee22e71f1e3409365674
#   Stored in directory: /root/.cache/pip/wheels/98/19/8e/e8648026db8b7ef3324ad9afa1f7c9109a7e7509846f693ed9
# Successfully built pdftotext
# Installing collected packages: pdftotext
# Successfully installed pdftotext-2.2.2

# %%
import PyPDF2
import spacy
from spacy.matcher import Matcher
import pdftotext
import pandas as pd
import os

# %%
! python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 7.2 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.10.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
path='/content/dataset' #file path for corpus
files = [os.path.join (path, f) for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
pdfs = []
for i in files:
    pdfs.append(i)

merger = PyPDF2.PdfFileMerger(strict=False)

for pdf in pdfs:
    merger.append(pdf)

merger.write("final.pdf")
# Out:
# PdfReadWarning: Multiple definitions in dictionary at byte 0x2379 for key /h.6dzabhgz4wnn [generic.py:588]
# PdfReadWarning: Multiple definitions in dictionary at byte 0x23d7 for key /h.xzo9n6yunfn [generic.py:588]

# %%
with open("final.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

# %%
finalpg=[]
for page in pdf:
    pg=page.strip()
    finalpg.append(pg)
print(finalpg[2])
# Out:
# Projects
#   RAVI SATVIK                                             Prediction of COVID-19 Infection Using Epidemiology
#   GORTHI
#                                                           Dataset
#                                                               We predicted and forecasted the COVID-19 outbreak in the
#                                                               World and India using a machine learning approach, the aim of
#                                                               the project is to provide data analysis of covid-19 using ML
#                       Data Scientist                          models SVM and polynomial regression. The SVM model
#                                                               performed better on India data, whereas the polynomial
#                                                               regression model performs better when considering the world
#                                                               data. We evaluated the models based on Mean Average Error.
#   Technical Skills
#                                                           Detection and Resolution of Rumors in Social Media:
#     ●   SAS Certified Specialist: Base Programming Using  A Survey
#         SAS 9.4
#                                                               - This project addresses the challenge of rumor stance
#     ●   Languages: Python, R                                  classification, which involves identifying the stances of users
#     ●   Packages: skLearn, Keras, spaCY                       towards the veracity of a rumor.
#     ●   Platforms: Anaconda, Jupyter Notebook, PyCharm        - We implemented an LSTM-based sequential model which takes
#                                                               in the sequences of source and their corresponding reply tweets
#                                                               as input and gives stances for all the underlying tweets
#                                                               - Since this is a classification problem, we used accuracy and F1
#   Contact                                                     macro averaged score to evaluate. The model performed with
#                                                               an accuracy of 0.43 and F1 macro score of 0.25.
# +91 7013057375
#                                                           Hate Speech and Fake News Detection
# ravisatvik.192@gmail.com
# linkedin.com/ravi-gorthi                                      - Over the past years, interest in online hate speech detection
#                                                               and, particularly, the automation of this task has continuously
# github.com/rgorthi                                            grown, along with the societal impact of the incident. This
#                                                               project describes a hate speech classification model based on
#                                                               Distil-BERT.
# Academic                                                      - This project also describes a fake news classification model
#                                                               based on GloVe embeddings for feature extraction followed by
# Qualifications                                                training an LSTM model.
#                                                               -The LSTM model performed with a weighted F1 score of 0.90.
#                                                               The distil- BERT model performed with an accuracy of 0.84.
# MASTER OF SCIENCE (Data Science)
# D.A.I.I.C.T, 2022
#                                                          Work Experience
# BACHELOR OF TECHNOLOGY(Computer Science
# and Engineering)                                          ModulusPI IT Solutions, Hyderabad
# SRM University, 2018                                      1 year as AR/VR Developer
#                                                              Worked on VR projects for HTC Vive, Oculus Rift, and Windows
#                                                              Mixed Reality using Unreal Engine.
#                                                               - Developed a VR Application for Patient- Doctor Interaction
# Skills                                                        - Built and developed a VR Real Estate Concept Visualization
#                                                               Tool
#     DATA ANALYSIS                                             - Worked on a VR Tool For Training and Evaluation Module for
#                                                               warehouse safety
#     MODEL BUILDING
#                                                               - Developed several in-house projects for POC
#     MACHINE LEARNING
#     DEEP LEARNING                                         AutoVRse, Bangalore                 6 Months of Internship
#     NATURAL LANGUAGE PROCESSING
#                                                              - Built a VR Experience of Service Centers in the Future for
#     MODEL DEPLOYMENT IN CLOUD                                Greaves Cotton, Chennai.
#                                                              - Built a VR model of a Bus, to view under custom exterior
#     VERSION CONTROL AND REPORT GENERATION                    settings, preset interiors, and lighting for a major automobile firm
#                                                              in Chennai.
#                                                              - Built a VR teaching and evaluation module for warehouse
#                                                              employees, for a tire manufacturing firm.

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(finalpg[0])


for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Sonnathi Sonnathi PROPN NNP compound Xxxxx True False
# Harika Harika PROPN NNP ROOT Xxxxx True False
#
#
#                               SPACE _SP
#      False False
# harikasonnathi22@gmail.com harikasonnathi22@gmail.com PROPN NNP ROOT xxxxdd@xxxx.xxx False False
# | | NUM CD nmod | False False
# +91 +91 NUM CD ROOT +dd False False
# 6303644378 6303644378 NUM CD nummod dddd False False
#
#
#                                    SPACE _SP
#      False False
# www.linkedin.com/in/harika-sonnathi www.linkedin.com/in/harika-sonnathi PUNCT -RRB- ROOT xxx.xxxx.xxx/xx/xxxx-xxxx False False
#
#
#  SPACE _SP
#  False False
# A a DET DT det X True True
# hard hard ADV RB advmod xxxx True False
# - - PUNCT HYPH punct - False False
# working work VERB VBG amod xxxx True False
# automobile automobile NOUN NN ROOT xxxx True False
#
#
#  SPACE _SP
#  False False
# enthusiast enthusiast NOUN NN amod xxxx True False
# with with ADP IN prep xxxx True True
# a a DET DT det x True True
# demonstrated demonstrate VERB VBN amod xxxx True False
#
#
#                                          SPACE _SP
#      False False
# EXPERIENCE experience ADV RB pobj XXXX True False
#
#
#  SPACE _SP
#  False False
# history history NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# working work VERB VBG pcomp xxxx True False
# with with ADP IN prep xxxx True True
# design design NOUN NN nmod xxxx True False
#                     SPACE _SP       False False
# TEAM TEAM PROPN NNP pobj XXXX True False
# UNWIRED UNWIRED PROPN NNP ROOT XXXX True False
# | | PROPN NNP dobj | False False
# SUSPENSION SUSPENSION NOUN NNS dobj XXXX True False
# AND and CCONJ CC cc XXX True True
# STEERING STEERING PROPN NNP compound XXXX True False
# ENGINEER ENGINEER PROPN NNP conj XXXX True False
#
#
#  SPACE _SP
#  False False
# and and CCONJ CC cc xxx True True
# manufacturing manufacturing NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# formula formula NOUN NN pobj xxxx True False
#                     SPACE _SP       False False
# Jul Jul PROPN NNP ROOT Xxx True False
# 2019 2019 NUM CD nummod dddd False False
# – – PUNCT : punct – False False
# Present Present PROPN NNP amod Xxxxx True False
#
#
#  SPACE _SP
#  False False
# student student NOUN NN compound xxxx True False
# race race NOUN NN compound xxxx True False
# car car NOUN NN appos xxx True False
# , , PUNCT , punct , False False
# seeking seek VERB VBG advcl xxxx True False
# for for ADP IN prep xxx True True
# an an DET DT det xx True True
#                           SPACE _SP       False False
# • • X ADD intj • False False
#       SPACE _SP     False False
# Designed design VERB VBN pobj Xxxxx True False
# and and CCONJ CC cc xxx True True
# fabricated fabricate VERB VBD conj xxxx True False
# a a DET DT det x True True
# formula formula ADJ JJ compound xxxx True False
# race race NOUN NN compound xxxx True False
# car car NOUN NN dobj xxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# competition competition NOUN NN compound xxxx True False
# SUPRA SUPRA PROPN NNP nmod XXXX True False
#
#
#  SPACE _SP
#  False False
# internship internship VERB VB compound xxxx True False
# opportunity opportunity NOUN NN pobj xxxx True False
# to to ADP IN prep xx True True
#                                                 SPACE _SP       False False
# SAE SAE PROPN NNP compound XXX True False
# INDIA INDIA PROPN NNP pobj XXXX True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# leverage leverage VERB VB ROOT xxxx True False
# my -PRON- DET PRP$ poss xx True True
# research research NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True True
#                                           SPACE _SP       False False
# • • X ADD conj • False False
#       SPACE _SP     False False
# Currently currently ADV RB advmod Xxxxx True False
# working work VERB VBG ROOT xxxx True False
# on on ADP IN prep xx True True
# design design NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# manufacturing manufacturing NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# car car NOUN NN pobj xxx True False
# for for ADP IN prep xxx True True
# Formula Formula PROPN NNP nmod Xxxxx True False
#
#
#  SPACE _SP
#  False False
# organizational organizational ADJ JJ amod xxxx True False
# skills skill NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
#                                                       SPACE _SP       False False
# Bharat Bharat PROPN NNP ROOT Xxxxx True False
# 2022 2022 NUM CD nummod dddd False False
# . . PUNCT . punct . False False
#
#
#                                               SPACE _SP
#      False False
# • • X XX ROOT • False False
#       SPACE _SP     False False
# Conducted conduct VERB VBN ROOT Xxxxx True False
# educative educative ADJ JJ amod xxxx True False
# workshops workshop NOUN NNS dobj xxxx True False
# for for ADP IN prep xxx True True
# first first ADJ JJ amod xxxx True True
# year year NOUN NN compound xxxx True False
# UG UG PROPN NNP compound XX True False
# students student NOUN NNS pobj xxxx True False
# during during ADP IN prep xxxx True True
#
#
#  SPACE _SP
#  False False
# EDUCATION EDUCATION PROPN NNP pobj XXXX True False
#                                                                                 SPACE _SP       False False
# Tathva Tathva PROPN NNP pobj Xxxxx True False
# 2019 2019 NUM CD nummod dddd False False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# NATIONAL NATIONAL PROPN NNP compound XXXX True False
# INSTITUTE INSTITUTE PROPN NNP nsubj XXXX True False
# OF of ADP IN prep XX True True
#
#
#  SPACE _SP
#  False False
# TECHNOLOGY TECHNOLOGY PROPN NNP pobj XXXX True False
# CALICUT CALICUT PROPN NNP ROOT XXXX True False
#
#
#                                          SPACE _SP
#      False False
# PROJECTS PROJECTS PROPN NNP intj XXXX True False
#
#
#  SPACE _SP
#  False False
# 2018 2018 NUM CD nummod dddd False False
# - - SYM SYM punct - False False
# 2022 2022 NUM CD nummod dddd False False
#                                                           SPACE _SP       False False
# FLOW FLOW PROPN NNP compound XXXX True False
# INDUCED INDUCED PROPN NNP compound XXXX True False
# VIBRATIONS VIBRATIONS PROPN NNP ROOT XXXX True False
# IN in ADP IN prep XX True True
# CANTILEVER CANTILEVER PROPN NNP pobj XXXX True False
# BEAM BEAM PROPN NNP pobj XXXX True False
# | | PROPN NNP compound | False False
# Analysis Analysis PROPN NNP ROOT Xxxxx True False
#
#
#  SPACE _SP
#  False False
# B. B. PROPN NNP compound X. False False
# Tech Tech PROPN NNP ROOT Xxxx True False
# in in ADP IN prep xx True True
# Mechanical Mechanical PROPN NNP amod Xxxxx True False
#                                       SPACE _SP       False False
# Mar Mar PROPN NNP pobj Xxx True False
# 2021-Ongoing 2021-ongoing NUM CD compound dddd-Xxxxx False False
# | | NUM CD appos | False False
# Under under ADP IN ROOT Xxxxx True True
# Guidance Guidance PROPN NNP pobj Xxxxx True False
# of of ADP IN prep xx True True
# Dr. Dr. PROPN NNP compound Xx. False False
# Ashesh Ashesh PROPN NNP compound Xxxxx True False
# Saha Saha PROPN NNP pobj Xxxx True False
#
#
#  SPACE _SP
#  False False
# Engineering Engineering PROPN NNP ROOT Xxxxx True False
#                                                           SPACE _SP       False False
# Working work VERB VBG ROOT Xxxxx True False
# on on ADP IN prep xx True True
# experimental experimental ADJ JJ amod xxxx True False
# analysis analysis NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# flow flow NOUN NN nmod xxxx True False
# induced induce VERB VBN amod xxxx True False
# vibrations vibration NOUN NNS pobj xxxx True False
# in in ADP IN prep xx True True
# a a DET DT det x True True
# cantilever cantilever NOUN NN nmod xxxx True False
# beam beam NOUN NN nmod xxxx True False
#
#
#  SPACE _SP
#  False False
# CGPA CGPA PROPN NNP pobj XXXX True False
# : : PUNCT : punct : False False
# 8.02 8.02 NUM CD appos d.dd False False
# ( ( PUNCT -LRB- punct ( False False
# till till SCONJ IN prep xxxx True False
# date date NOUN NN pobj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
#                                     SPACE _SP       False False
# corresponding correspond VERB VBG ROOT xxxx True False
# to to ADP IN prep xx True True
# various various ADJ JJ amod xxxx True True
# parameters parameter NOUN NNS pobj xxxx True False
# like like SCONJ IN prep xxxx True False
# flow flow NOUN NN compound xxxx True False
# velocity velocity NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# dimensions dimension NOUN NNS conj xxxx True False
# of of ADP IN prep xx True True
# beam beam NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# By by ADP IN prep Xx True True
#
#
#                                          SPACE _SP
#      False False
# means mean NOUN NNS nsubj xxxx True False
# of of ADP IN prep xx True True
# various various ADJ JJ amod xxxx True True
# control control NOUN NN compound xxxx True False
# system system NOUN NN pobj xxxx True False
# approaches approach VERB VBZ ROOT xxxx True False
# a a DET DT det x True True
# design design NOUN NN nsubjpass xxxx True False
# is be AUX VBZ auxpass xx True True
# mathematically mathematically ADV RB advmod xxxx True False
# modelled model VERB VBN ccomp xxxx True False
# to to ADP IN aux xx True True
#
#
#  SPACE _SP
#  False False
# SRI SRI PROPN NNP compound XXX True False
# CHAITANYA CHAITANYA PROPN NNP compound XXXX True False
# JUNIOR JUNIOR PROPN NNP nsubj XXXX True False
#                                         SPACE _SP       False False
# qualitatively qualitatively ADV RB advmod xxxx True False
# match match VERB VBP xcomp xxxx True False
# experimental experimental ADJ JJ amod xxxx True False
# results result NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# KALASALA KALASALA PROPN NNP ROOT XXXX True False
#
#
#  SPACE _SP
#  False False
# 2016 2016 NUM CD nummod dddd False False
# - - SYM SYM punct - False False
# 2018 2018 NUM CD prep dddd False False
#                                                           SPACE _SP       False False
# POSITIONS position NOUN NNS appos XXXX True False
# OF of ADP IN prep XX True True
# RESPONSIBILITY RESPONSIBILITY PROPN NNP pobj XXXX True False
#
#
#  SPACE _SP
#  False False
# Intermediate Intermediate PROPN NNP ROOT Xxxxx True False
#
#
#                                          SPACE _SP
#      False False
# TRAINING TRAINING PROPN NNP conj XXXX True False
# & & CCONJ CC cc & False False
# PLACEMENT PLACEMENT PROPN NNP conj XXXX True False
# CELL CELL PROPN NNP compound XXXX True False
# NITC NITC PROPN NNP compound XXXX True False
# |PLACEMENT |PLACEMENT PROPN NNP conj |XXXX False False
#
#
#  SPACE _SP
#  False False
# Marks Marks PROPN NNP ROOT Xxxxx True False
# : : PUNCT : punct : False False
# 978/1000 978/1000 NUM CD ROOT ddd/dddd False False
# in in ADP IN prep xx True True
# TSBIE TSBIE PROPN NNP nmod XXXX True False
#
#
#                                          SPACE _SP
#      False False
# REPRESENTATIVE representative NOUN NN pobj XXXX True False
#
#
#                                          SPACE _SP
#      False False
# Jun Jun PROPN NNP ROOT Xxx True False
# 2020 2020 NUM CD nummod dddd False False
# – – PUNCT : punct – False False
# Present Present PROPN NNP ROOT Xxxxx True False
#
#
#  SPACE _SP
#  False False
# CHAITANYA CHAITANYA PROPN NNP compound XXXX True False
# CENTRAL CENTRAL PROPN NNP ROOT XXXX True False
#                                               SPACE _SP       False False
# Being be AUX VBG ROOT Xxxxx True True
# a a DET DT det x True True
# PR pr NOUN NN attr XX True False
# served serve VERB VBD acl xxxx True False
# as as SCONJ IN prep xx True True
# the the DET DT det xxx True True
# primary primary ADJ JJ amod xxxx True False
# point point NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# contact contact NOUN NN pobj xxxx True False
# for for ADP IN prep xxx True True
# each each DET DT det xxxx True True
# student student NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# our -PRON- DET PRP$ poss xxx True True
#
#
#  SPACE _SP
#  False False
# SCHOOL SCHOOL PROPN NNP pobj XXXX True False
#                                                                     SPACE _SP       False False
# department department NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Despite despite SCONJ IN prep Xxxxx True False
# academic academic ADJ JJ amod xxxx True False
# pressure pressure NOUN NN pobj xxxx True False
# was be AUX VBD ROOT xxx True True
# very very ADV RB advmod xxxx True True
# attentive attentive ADJ JJ acomp xxxx True False
# to to ADP IN prep xx True True
# accuracy accuracy NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# detail detail NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# 2011 2011 NUM CD nummod dddd False False
# - - SYM SYM punct - False False
# 2016 2016 NUM CD prep dddd False False
#                                                           SPACE _SP       False False
# Received receive VERB VBD compound Xxxxx True False
# applause applause NOUN NN ROOT xxxx True False
# for for ADP IN prep xxx True True
# unblemished unblemished ADJ JJ amod xxxx True False
# honesty honesty NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# at at ADP IN conj xx True True
# most most ADJ JJS amod xxxx True True
# patience patience NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# High High PROPN NNP compound Xxxx True False
# School School PROPN NNP nmod Xxxxx True False
#
#
#  SPACE _SP
#  False False
# CGPA cgpa NOUN NN ROOT XXXX True False
# : : PUNCT : punct : False False
# 9.8 9.8 NUM CD appos d.d False False
# in in ADP IN prep xx True True
# AISSE AISSE PROPN NNP pobj XXXX True False
#                                             SPACE _SP       False False
# MAGAZINE MAGAZINE PROPN NNP compound XXXX True False
# COMMITTEE COMMITTEE PROPN NNP compound XXXX True False
# NITC NITC PROPN NNP compound XXXX True False
# | | PROPN NNP punct | False False
# CONTENT CONTENT PROPN NNP compound XXXX True False
# WRITER WRITER PROPN NNP appos XXXX True False
# & & CCONJ CC cc & False False
# EDITOR EDITOR PROPN NNP conj XXXX True False
#
#
#                                          SPACE _SP
#      False False
# Jun Jun PROPN NNP npadvmod Xxx True False
# 2020 2020 NUM CD nummod dddd False False
# – – PUNCT : punct – False False
# Present present ADJ JJ ROOT Xxxxx True False
#
#
#                                          SPACE _SP
#      False False
# Major major ADJ JJ amod Xxxxx True False
# contribution contribution NOUN NN ROOT xxxx True False
# made make VERB VBN acl xxxx True True
# in in ADP IN prep xx True True
# writing writing NOUN NN pcomp xxxx True False
# and and CCONJ CC cc xxx True True
# editing edit VERB VBG conj xxxx True False
# articles article NOUN NNS dobj xxxx True False
# for for ADP IN prep xxx True True
# NITC NITC PROPN NNP pobj XXXX True False
# ’s ’s PART POS punct ’x False True
# 2019 2019 NUM CD ROOT dddd False False
# annual annual ADJ JJ ROOT xxxx True False
#
#
#  SPACE _SP
#  False False
# SKILLS SKILLS PROPN NNP compound XXXX True False
#                                                                     SPACE _SP       False False
# magazine magazine NOUN NN npadvmod xxxx True False
# . . PUNCT . punct . False False
# Besides besides SCONJ IN prep Xxxxx True True
# publishing publish VERB VBG pcomp xxxx True False
# magazines magazine NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# organized organize VERB VBN ROOT xxxx True False
# informative informative ADJ JJ amod xxxx True False
# lectures lecture NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# debates debate NOUN NNS conj xxxx True False
# and and CCONJ CC cc xxx True True
#
#
#  SPACE _SP
#  False False
# DESIGN DESIGN PROPN NNP compound XXXX True False
# SOFTWARES SOFTWARES PROPN NNP conj XXXX True False
#                                                 SPACE _SP       False False
# movie movie NOUN NN compound xxxx True False
# screenings screening NOUN NNS conj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# • • X ADD nmod • False False
# CATIA CATIA PROPN NNP compound XXXX True False
# V5 v5 NOUN NN ROOT Xd False False
# R20 R20 PROPN NNP punct Xdd False False
# • • PROPN NNP compound • False False
# SolidWorks SolidWorks PROPN NNP nsubj XxxxxXxxxx True False
#                           SPACE _SP       False False
# TELUGU TELUGU PROPN NNP compound XXXX True False
# STREETPLAY STREETPLAY PROPN NNP dative XXXX True False
# TEAM TEAM PROPN NNP ROOT XXXX True False
# | | PROPN NNP punct | False False
# MEMBER MEMBER PROPN NNP ROOT XXXX True False
#
#
#  SPACE _SP
#  False False
# •Solid •solid ADV RB ROOT •Xxxxx False False
# Edge edge NOUN NN dobj Xxxx True False
# • • X ADD compound • False False
# AutoCAD AutoCAD PUNCT : ROOT XxxxXXX True False
#                                       SPACE _SP       False False
# Performed perform VERB VBN ROOT Xxxxx True False
# in in ADP IN prep xx True True
# Ragam Ragam PROPN NNP pobj Xxxxx True False
# 2019 2019 NUM CD nummod dddd False False
#
#
#  SPACE _SP
#  False False
# ANALYSIS ANALYSIS PROPN NNP compound XXXX True False
# SOFTWARES SOFTWARES PROPN NNP ROOT XXXX True False
#
#
#  SPACE _SP
#  False False
# • • X ADD ROOT • False False
# Lotus Lotus PROPN NNP compound Xxxxx True False
# Suspension Suspension PROPN NNP compound Xxxxx True False
# Analysis Analysis PROPN NNP nmod Xxxxx True False
#                           SPACE _SP       False False
# LEAGUE LEAGUE PROPN NNP ROOT XXXX True False
# OF of ADP IN prep XX True True
# MACHINES MACHINES PROPN NNP compound XXXX True False
# EVENT EVENT PROPN NNP pobj XXXX True False
# | | PROPN NNP punct | False False
# EVENT EVENT PROPN NNP compound XXXX True False
# MANAGER manager NOUN NN nmod XXXX True False
#
#
#  SPACE _SP
#  False False
# software software NOUN NN nmod xxxx True False
# • • PUNCT . compound • False False
# ANSYS ANSYS PROPN NNP ROOT XXXX True False
# ( ( PUNCT -LRB- punct ( False False
# Basics Basics PROPN NNP appos Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
#                               SPACE _SP       False False
# For for ADP IN ROOT Xxx True True
# Tathva Tathva PROPN NNP pobj Xxxxx True False
# 2019 2019 NUM CD nummod dddd False False
#
#
#  SPACE _SP
#  False False
# LANGUAGES LANGUAGES PROPN NNP appos XXXX True False
#
#
#  SPACE _SP
#  False False
# • • X ADD ROOT • False False
# Python• python• NOUN NN nummod Xxxxx• False False
# C c NOUN NN ROOT X True False
#
#
#  SPACE _SP
#  False False
# TOOLS TOOLS PROPN NNP ROOT XXXX True False
#                                                                       SPACE _SP       False False
# COMMUNITY COMMUNITY PROPN NNP compound XXXX True False
# INVOLVEMENT INVOLVEMENT PROPN NNP ROOT XXXX True False
#
#
#  SPACE _SP
#  False False
# • • PUNCT . compound • False False
# GIT GIT PROPN NNP ROOT XXX True False
# ( ( PUNCT -LRB- punct ( False False
# Basics Basics PROPN NNP appos Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# • • PUNCT . compound • False False
# MATLAB MATLAB PROPN NNP ROOT XXXX True False
#                                   SPACE _SP       False False
# • • X ADD nmod • False False
# Voluntary voluntary ADJ JJ compound Xxxxx True False
# member member NOUN NN ROOT xxxx True False
# of of ADP IN prep xx True True
# Hospitality Hospitality PROPN NNP compound Xxxxx True False
# Committee Committee PROPN NNP pobj Xxxxx True False
# in in ADP IN prep xx True True
# Ragam Ragam PROPN NNP pobj Xxxxx True False
# 2020 2020 NUM CD nummod dddd False False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# •MS •MS PROPN NNP ROOT •XX False False
# Office Office PROPN NNP ROOT Xxxxx True False
#                                                             SPACE _SP       False False
# • • X ADD nsubj • False False
# Held hold VERB VBD ROOT Xxxx True False
# a a DET DT det x True True
# school school NOUN NN compound xxxx True False
# debutante debutante NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# as as SCONJ IN mark xx True True
# a a DET DT det x True True
# part part NOUN NN nsubj xxxx True True
# of of ADP IN prep xx True True
# it -PRON- PRON PRP pobj xx True True
# organized organize VERB VBD advcl xxxx True False
# a a DET DT det x True True
# plethora plethora NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# literary literary ADJ JJ amod xxxx True False
# events event NOUN NNS pobj xxxx True False
# for for ADP IN prep xxx True True
#
#
#                                          SPACE _SP
#      False False
# secondary secondary ADJ JJ amod xxxx True False
# school school NOUN NN compound xxxx True False
# students student NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#                                          SPACE _SP
#      False False
# • • X ADD nsubj • False False
# Volunteered volunteer VERB VBN ROOT Xxxxx True False
# for for ADP IN prep xxx True True
# an an DET DT det xx True True
# Electronics Electronics PROPN NNP compound Xxxxx True False
# repair repair NOUN NN compound xxxx True False
# drive drive NOUN NN pobj xxxx True False
# during during ADP IN prep xxxx True True
# Kerala Kerala PROPN NNP compound Xxxxx True False
# floods flood NOUN NNS pobj xxxx True False
# in in ADP IN prep xx True True
# 2019 2019 NUM CD pobj dddd False False
# . . PUNCT . punct . False False

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.6.0.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 2.5 MB/s
# Collecting pdfminer.six==20211012
#   Downloading pdfminer.six-20211012-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 11.5 MB/s
# Collecting Pillow>=8.4
#   Downloading Pillow-9.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 44.7 MB/s
# Collecting Wand>=0.6.7
#   Downloading Wand-0.6.7-py2.py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 45.6 MB/s
# Requirement already satisfied: chardet in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20211012->pdfplumber) (3.0.4)
# Collecting cryptography
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 28.2 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six==20211012->pdfplumber) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six==20211012->pdfplumber) (2.21)
# Building wheels for collected packages: pdfplumber
#   Building wheel for pdfplumber (setup.py) ... done
#   Created wheel for pdfplumber: filename=pdfplumber-0.6.0-py3-none-any.whl size=33688 sha256=1e67b28aa2aed330763002c13cd74055899873158768c8435947cb2633e70d03
#   Stored in directory: /root/.cache/pip/wheels/58/56/fe/2e93d842ffa9ea97746c1ab253d43502ed61c0689361a0224e
# Successfully built pdfplumber
# Installing collected packages: cryptography, Wand, Pillow, pdfminer.six, pdfplumber
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-9.0.1 Wand-0.6.7 cryptography-36.0.1 pdfminer.six-20211012 pdfplumber-0.6.0

# %%
# !unzip '/content/dataset.zip'
# Out:
# Archive:  /content/dataset.zip
#    creating: dataset/
#   inflating: dataset/Harika Sonnathi Resume 2022 2.pdf
#   inflating: dataset/KetanPawarResume.pdf
#   inflating: dataset/Mandar bhoir Resume (1)_compressed.pdf
#   inflating: dataset/pararthdave_Resume.pdf
#   inflating: dataset/Priyanka_RaikwarRESUME.pdf
#   inflating: dataset/priyanka_resume(8).pdf
#   inflating: dataset/ravisatvik.192_Resume.pdf
#   inflating: dataset/YOGAPRIYA H_RESUME.pdf

# %%
temp = """3D printing
Acting
Aeromodeling
Air sports
Airbrushing
Aircraft Spotting
Airsoft
Airsofting
Amateur astronomy
Amateur geology
Amateur Radio
American football
Animal fancy
Animals/pets/dogs
Antiquing
Antiquities
Aqua-lung
Aquarium (Freshwater & Saltwater)
Archery
Art collecting
Arts
Association football
Astrology
Astronomy
Audiophilia
Australian rules football
Auto audiophilia
Auto racing
Backgammon
Backpacking
Badminton
Base Jumping
Baseball
Basketball
Baton Twirling
Beach Volleyball
Beach/Sun tanning
Beachcombing
Beadwork
Beatboxing
Becoming A Child Advocate
Beekeeping
Bell Ringing
Belly Dancing
Bicycle Polo
Bicycling
Billiards
Bird watching
Birding
Birdwatching
Blacksmithing
Blogging
BMX
Board games
Board sports
BoardGames
Boating
Body Building
Bodybuilding
Bonsai Tree
Book collecting
Bookbinding
Boomerangs
Bowling
Boxing
Brazilian jiu-jitsu
Breakdancing
Brewing Beer
Bridge
Bridge Building
Bringing Food To The Disabled
Building A House For Habitat For Humanity
Building Dollhouses
Bus spotting
Butterfly Watching
Button Collecting
Cake Decorating
Calligraphy
Camping
Candle making
Canoeing
Car Racing
Card collecting
Cartooning
Casino Gambling
Cave Diving
Ceramics
Cheerleading
Chess
Church/church activities
Cigar Smoking
Climbing
Cloud Watching
Coin Collecting
Collecting
Collecting Antiques
Collecting Artwork
Collecting Hats
Collecting Music Albums
Collecting RPM Records
Collecting Sports Cards (Baseball, Football, Basketball, Hockey)
Collecting Swords
Color guard
Coloring
Comic book collecting
Compose Music
Computer activities
Computer programming
Conworlding
Cooking
Cosplay
Cosplaying
Couponing
Crafts
Crafts (unspecified)
Creative writing
Cricket
Crochet
Crocheting
Cross-Stitch
Crossword Puzzles
Cryptography
Curling
Cycling
Dance
Dancing
Darts
Debate
Deltiology (postcard collecting)
Diecast Collectibles
Digital arts
Digital Photography
Disc golf
Do it yourself
Dodgeball
Dog sport
Dolls
Dominoes
Dowsing
Drama
Drawing
Driving
Dumpster Diving
Eating out
Educational Courses
Electronics
Element collecting
Embroidery
Entertaining
Equestrianism
Exercise (aerobics, weights)
Exhibition drill
Falconry
Fast cars
Felting
Fencing
Field hockey
Figure skating
Fire Poi
Fishing
Fishkeeping
Flag Football
Floorball
Floral Arrangements
Flower arranging
Flower collecting and pressing
Fly Tying
Flying
Footbag
Football
Foraging
Foreign language learning
Fossil hunting
Four Wheeling
Freshwater Aquariums
Frisbee Golf – Frolf
Gambling
Games
Gaming (tabletop games and role-playing games)
Garage Saleing
Gardening
Genealogy
Geocaching
Ghost hunting
Glassblowing
Glowsticking
Gnoming
Go
Go Kart Racing
Going to movies
Golf
Golfing
Gongoozling
Graffiti
Grip Strength
Guitar
Gun Collecting
Gunsmithing
Gymnastics
Gyotaku
Handball
Handwriting Analysis
Hang gliding
Herping
Hiking
Home Brewing
Home Repair
Home Theater
Homebrewing
Hooping
Horse riding
Hot air ballooning
Hula Hooping
Hunting
Ice hockey
Ice skating
Iceskating
Illusion
Impersonations
Inline skating
Insect collecting
Internet
Inventing
Jet Engines
Jewelry Making
Jigsaw Puzzles
Jogging
Judo
Juggling
Jukskei
Jump Roping
Kabaddi
Kart racing
Kayaking
Keep A Journal
Kitchen Chemistry
Kite Boarding
Kite flying
Kites
Kitesurfing
Knapping
Knife making
Knife throwing
Knitting
Knotting
Lacemaking
Lacrosse
Lapidary
LARPing
Laser tag
Lasers
Lawn Darts
Learn to Play Poker
Learning A Foreign Language
Learning An Instrument
Learning To Pilot A Plane
Leather crafting
Leathercrafting
Lego building
Legos
Letterboxing
Listening to music
Locksport
Machining
Macramé
Macrame
Magic
Mahjong
Making Model Cars
Marbles
Marksmanship
Martial arts
Matchstick Modeling
Meditation
Metal detecting
Meteorology
Microscopy
Mineral collecting
Model aircraft
Model building
Model Railroading
Model Rockets
Modeling Ships
Models
Motor sports
Motorcycles
Mountain Biking
Mountain Climbing
Mountaineering
Movie and movie memorabilia collecting
Mushroom hunting/Mycology
Musical Instruments
Nail Art
Needlepoint
Netball
Nordic skating
Orienteering
Origami
Owning An Antique Car
Paintball
Painting
Papermache
Papermaking
Parachuting
Paragliding or Power Paragliding
Parkour
People Watching
Photography
Piano
Pigeon racing
Pinochle
Pipe Smoking
Planking
Playing music
Playing musical instruments
Playing team sports
Poker
Pole Dancing
Polo
Pottery
Powerboking
Protesting
Puppetry
Puzzles
Pyrotechnics
Quilting
R/C Boats
R/C Cars
R/C Helicopters
R/C Planes
Racing Pigeons
Racquetball
Radio-controlled car racing
Rafting
Railfans
Rappelling
Rapping
Reading
Reading To The Elderly
Record collecting
Relaxing
Renaissance Faire
Renting movies
Rescuing Abused Or Abandoned Animals
Robotics
Rock balancing
Rock climbing
Rock Collecting
Rockets
Rocking AIDS Babies
Roleplaying
Roller derby
Roller skating
Rugby
Rugby league football
Running
Sailing
Saltwater Aquariums
Sand art
Sand Castles
Scrapbooking
Scuba diving
Sculling or Rowing
Sculpting
Sea glass collecting
Seashell collecting
Self Defense
Sewing
Shark Fishing
Shooting
Shooting sport
Shopping
Shortwave listening
Singing
Singing In Choir
Skateboarding
Skating
Skeet Shooting
Sketching
Skiing
Skimboarding
Sky Diving
Skydiving
Slack Lining
Slacklining
Sleeping
Slingshots
Slot car racing
Snorkeling
Snowboarding
Soap Making
Soapmaking
Soccer
Socializing with friends/neighbors
Speed Cubing (rubix cube)
Speed skating
Spelunkering
Spending time with family/kids
Sports
Squash
Stamp Collecting
Stand-up comedy
Stone collecting
Stone skipping
Storm Chasing
Storytelling
String Figures
Sudoku
Surf Fishing
Surfing
Survival
Swimming
Table football
Table tennis
Taekwondo
Tai chi
Tatting
Taxidermy
Tea Tasting
Tennis
Tesla Coils
Tetris
Textiles
Texting
Tombstone Rubbing
Tool Collecting
Tour skating
Toy Collecting
Train Collecting
Train Spotting
Trainspotting
Traveling
Treasure Hunting
Trekkie
Triathlon
Tutoring Children
TV watching
Ultimate Frisbee
Urban exploration
Vehicle restoration
Video game collecting
Video Games
Video gaming
Videophilia
Vintage cars
Violin
Volleyball
Volunteer
Walking
Warhammer
Watching movies
Watching sporting events
Water sports
Weather Watcher
Web surfing
Weightlifting
Windsurfing
Wine Making
Wingsuit Flying
Wood carving
Woodworking
Working In A Food Pantry
Working on cars
World Record Breaking
Worldbuilding
Wrestling
Writing
Writing Music
Writing Songs
Yo-yoing
Yoga
YoYo
Ziplining
Zumba"""

# %%
import pdfplumber


x0 = 0    # Distance of left side of character from left side of page.
x1 = 0.6  # Distance of right side of character from left side of page.
y0 = 0  # Distance of bottom of character from bottom of page.
y1 = 1  # Distance of top of character from bottom of page.

all_content = []
with pdfplumber.open('/content/dataset/Priyanka_RaikwarRESUME.pdf') as pdf:
    for i, page in enumerate(pdf.pages):
        width = page.width
        height = page.height

        # Crop pages
        left_bbox = (x0*float(width), y0*float(height), x1*float(width), y1*float(height))
        page_crop = page.crop(bbox=left_bbox)
        left_text = page_crop.extract_text()
        #print(left_text)
        
        left_bbox = (0.5*float(width), y0*float(height), 1*float(width), y1*float(height))
        page_crop = page.crop(bbox=left_bbox)
        right_text = page_crop.extract_text()
    #    print(right_text)
    #    page_context = '\n'.join([left_text, right_text])
    #    all_content.append(page_context)
    #    if i < 2:  # help you see the merged first two pages
    #        print(page_context)

# %%
nlp_text=nlp(left_text)

tokens = [token.text for token in nlp_text if not token.is_stop]
for j,i in enumerate(tokens):
  if i.lower()=='hobbies':
    j+=1
    x=tokens[j]
    ans=''
    while j<len(tokens) or x!='\n':
      if (nlp(x)[0].pos_ in ['NOUN','VERB'] or x.lower() in temp.lower()):
        ans=ans+x+' '
        if x=='\n':
          break
        if j<len(tokens) and nlp(tokens[j])[0].pos_ == 'SPACE':
          j+=1
        if x=='\n':
          break
        if (nlp(x)[0].pos_=='NOUN' or nlp(x)[0].pos_=='VERB') and j<len(tokens) and nlp(tokens[j])[0].pos_ not in ['NOUN','SPACE','PUNCT']:
          ans=ans+ ','
      j+=1
      if j>=len(tokens) or x=='\n':
        break
      x=tokens[j]
    ans=ans.replace(' ,',',')
    print(ans)
    
    break

# %%
print(nlp_text)
# Out:
# PRIYANKA R
#
#
#
#
# CONTACT  OBJECTIVE
# H.No:33 Shivasthali Colony, Makronia  To Secure a position w
# Sagar.  and abilities to the gro
# professional career.
# 7974849362
# Priyankajma17@gmail.com
#
# EDUCATION  PROJECTS
# MNNIT ALLAHABAD, PRAYAGRAJ  LIBRARY MANAGEME
# -2019
# Master of Computer Applications
# • Students and admin ca
# CPI: 8.87 (Till 5th sem)                -2022
# • Admin can add books
#
# Dr. HARI SINGH GOUR UNIVERSITY |  • Registered students de
# SAGAR  • Admin can check statis
# Bachelor of Computer Applications  • Calculate fine for retur
# CGPA:9.12                                 -2018
#
#
# VIDEO CONTROLLING
# D.M.A SAGAR
# -2021
# CLASS XII | CBSE
# • Libraries used are Ope
# Percentage: 71.4%                     -2015
#   • Web camera will detec
# D.M.A SAGAR  to it.
# CLASS X | CBSE  • Operation included Pa
# CGPA: 8.0                                  -2013
#
# FIND VACCINATION S
# -2021
# • Using the Pycharm pla
# • Can check vaccination
# AREA OF INTEREST  SKILLS
#   Data structure and Algorithm  PROGRAMMING:
# Familiar with: C/C++, M
#   DBMS
# Basics:           Java, Pyt
#   Operating system
#
#   TECHNICAL:
# Familiar with: Anacond
#
# ACHIEVEMEN
# HOBBIES
# ● Certificate of Complet
#   To explore new technologies.  Specialist(2020)” by(ICS
#   To read chronicles of freedom  ● Member of Volleyball
# fighters.
# ● Got a gold medal in ka
#   Drawing and Sketching
# ● Worked as Class Rep
# ● Got second position in

# %%
print(nlp_text)
# Out:
# PRIYANKA R
#
#
#
#
# CONTACT  OBJECTIVE
# H.No:33 Shivasthali Colony, Makronia  To Secure a position w
# Sagar.  and abilities to the gro
# professional career.
# 7974849362
# Priyankajma17@gmail.com
#
# EDUCATION  PROJECTS
# MNNIT ALLAHABAD, PRAYAGRAJ  LIBRARY MANAGEME
# -2019
# Master of Computer Applications
# • Students and admin ca
# CPI: 8.87 (Till 5th sem)                -2022
# • Admin can add books
#
# Dr. HARI SINGH GOUR UNIVERSITY |  • Registered students de
# SAGAR  • Admin can check statis
# Bachelor of Computer Applications  • Calculate fine for retur
# CGPA:9.12                                 -2018
#
#
# VIDEO CONTROLLING
# D.M.A SAGAR
# -2021
# CLASS XII | CBSE
# • Libraries used are Ope
# Percentage: 71.4%                     -2015
#   • Web camera will detec
# D.M.A SAGAR  to it.
# CLASS X | CBSE  • Operation included Pa
# CGPA: 8.0                                  -2013
#
# FIND VACCINATION S
# -2021
# • Using the Pycharm pla
# • Can check vaccination
# AREA OF INTEREST  SKILLS
#   Data structure and Algorithm  PROGRAMMING:
# Familiar with: C/C++, M
#   DBMS
# Basics:           Java, Pyt
#   Operating system
#
#   TECHNICAL:
# Familiar with: Anacond
#
# ACHIEVEMEN
# HOBBIES
# ● Certificate of Complet
#   To explore new technologies.  Specialist(2020)” by(ICS
#   To read chronicles of freedom  ● Member of Volleyball
# fighters.
# ● Got a gold medal in ka
#   Drawing and Sketching
# ● Worked as Class Rep
# ● Got second position in

# %%
type(nlp_text)
# Out:
# spacy.tokens.doc.Doc

# %%
type(left_text)
# Out:
# str

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
nlp_text=nlp(right_text)

tokens = [token.text for token in nlp_text if not token.is_stop]
for j,i in enumerate(tokens):
  if i.lower()=='hobbies':
    j+=1
    x=tokens[j]
    ans=''
    while j<len(tokens) or x!='\n':
      if (nlp(x)[0].pos_ in ['NOUN','VERB'] or x.lower() in temp.lower()):
        ans=ans+x+' '
        if x=='\n':
          break
        if j<len(tokens) and nlp(tokens[j])[0].pos_ == 'SPACE':
          j+=1
        if x=='\n':
          break
        if (nlp(x)[0].pos_=='NOUN' or nlp(x)[0].pos_=='VERB') and j<len(tokens) and nlp(tokens[j])[0].pos_ not in ['NOUN','SPACE','PUNCT']:
          ans=ans+ ','
      j+=1
      if j>=len(tokens) or x=='\n':
        break
      x=tokens[j]
    ans=ans.replace(' ,',',')
    print(ans)
    
    break

# %%
print(nlp_text)
# Out:
#
# KA RAIKWAR
#
# CTIVE
# re a position where I can efficiently contribute my skills
# ties to the growth of organization and build my
# onal career.
# ECTS
# Y MANAGEMENT SYSTEM | JAVA | MySQL
# s and admin can login with username and password.
# an add books in database with unique book id.
# ed students details are available.
# an check statistics of issued and returned book.
# e fine for returning the book late.
# ONTROLLING BY HAND GESTURE | PYTHON
# s used are OpenCV and NumPy.
# mera will detect the hand gesture & respond corresponding
# on included Pause, play, volume up- down and fast forward.
# CCINATION SLOT | PYTHON | JSON
# e Pycharm platform and Postman.
# ck vaccinations slots by PIN code and date.
# LS
# AMMING:
# with: C/C++, MySQL
#          Java, Python , HTML, MongoDB
# CAL:
# with: Anaconda, Postman, Net beans, Visual Studio.
# EVEMENTS
# ate of Completion of “ Certified Network Security
# (2020)” by(ICSI)
# r of Volleyball team(2019) at MNNIT Allahabad
# old medal in kabaddi (2019) at MNNIT Allahabad.
#  as Class Representative in BCA.
# ond position in National Science Day(2017) Event
